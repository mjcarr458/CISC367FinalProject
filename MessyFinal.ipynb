# %%
import pandas as pd

df = pd.read_csv("State_Employee_Credit_Card_Transactions.csv");
df.head()
# Out:
#    FISCAL_YEAR  FISCAL_PERIOD                     DEPT_NAME  \
# 0         2016              1                 DEPT OF STATE
# 1         2016              1     DEL TECH AND COMM COLLEGE
# 2         2016              1  DEPT OF HEALTH AND SOCIAL SV
# 3         2016              1                         LEGAL
# 4         2016              1                         LEGAL
#
#                          DIV_NAME                  MERCHANT  \
# 0   HUMAN RELATIONSCOMM FOR WOMEN        C/B GROUP REVERSAL
# 1  DTCC - OFFICE OF THE PRESIDENT                CA PUCCINO
# 2         GOVERNOR BACON HOSPITAL         CHARGEBACK CREDIT
# 3      OFFICE OF ATTORNEY GENERAL  DOJ INTERNAL TRANSACTION
# 4      OFFICE OF ATTORNEY GENERAL  DOJ INTERNAL TRANSACTION
#
#                    CAT_DESCR    TRANS_DT  MERCHANDISE_AMT
# 0       INTERNAL TRANSACTION  04/02/2015           105.73
# 1  EATING PLACES RESTAURANTS  05/27/2015             3.79
# 2       INTERNAL TRANSACTION  05/29/2015         -1678.57
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df["DEPT_NAME"].unique()
# Out:
# array(['DEPT OF STATE', 'DEL TECH AND COMM COLLEGE',
#        'DEPT OF HEALTH AND SOCIAL SV', 'LEGAL',
#        'KUUMBA ACADEMY CHARTER SCHOOL', 'COLONIAL SCHOOL DISTRICT',
#        'DEPT OF TRANSPORTATION', 'DEPT OF CORRECTIONS',
#        'DEPT OF EDUCATION', 'DEPT OF NATRL RES AND ENV CONT',
#        'MOT CHARTER SCHOOL', 'APPOQUINIMINK SCHOOL DISTRICT',
#        'BRANDYWINE SCHOOL DISTRICT', 'CAPE HENLOPEN SCHOOL DISTRICT',
#        'DE COLLEGE PREPARATORY ACADEMY', 'DEPT OF ELECTIONS',
#        'DEPT OF FINANCE', 'DEPT OF SAFETY AND HOMELAND',
#        'EAST SIDE CHARTER SCHOOL', 'EXECUTIVE',
#        'FIRE PREVENTION COMMISSION', 'INDIAN RIVER SCHOOL DISTRICT',
#        'JUDICIAL', 'LEGISLATIVE BRANCH', 'NEW CASTLE COUNTY VO-TECH SCH',
#        'ODYSSEY CHARTER', 'POLYTECH SCHOOL DISTRICT',
#        'RED CLAY CONSOLIDATED SCH DIST', 'SEAFORD SCHOOL DISTRICT',
#        'SVS FR CHILDREN YOUTH FAMILIES', 'DEPT OF LABOR',
# ...

# %%
df["DIV_NAME"].unique()
# Out:
# array(['HUMAN RELATIONSCOMM FOR WOMEN', 'DTCC - OFFICE OF THE PRESIDENT',
#        'GOVERNOR BACON HOSPITAL', 'OFFICE OF ATTORNEY GENERAL',
#        'KUUMBA ACADEMY CHARTER SCHOOL', 'COLONIAL SCHOOL DISTRICT',
#        'MAINTENANCE DISTRICTS', 'DELAWARE CORRECTIONAL INDUSTRI',
#        'DEPARTMENT OF EDUCATION', 'SUBSTANCE ABUSE',
#        'PARKS AND RECREATION', 'PUBLIC SERVICE COMMISSION',
#        'MOT CHARTER SCHOOL', 'APPOQUINIMINK SCHOOL DISTRICT',
#        'BRANDYWINE SCHOOL DISTRICT', 'CAPE HENLOPEN SCHOOL DISTRICT',
#        'DE COLLEGE PREPARATORY ACADEMY', 'DTCC - STANTON CAMPUS',
#        'DTCC - TERRY CAMPUS', 'OWENS CAMPUS', 'FACILITIES MAINTENANCE',
#        'FOOD SERVICES', 'PROBATION AND PAROLE',
#        'SUSSEX CORRECTIONAL INST', 'KENT COUNTY ELECTIONS', 'ACCOUNTING',
#        'STATE SERVICE CENTERS', 'AIR QUALITY', 'FISH AND WILDLIFE',
#        'CAPITOL POLICE', 'DIV OF ALCOHOL AND TOBAC ENF',
# ...

# %%
UD = df.query('DEPT_NAME == "DEPARTMENT OF HUMAN RESOURCES"')
UD
# Out:
#          FISCAL_YEAR  FISCAL_PERIOD                      DEPT_NAME  \
# 375023          2018              1  DEPARTMENT OF HUMAN RESOURCES
# 375024          2018              1  DEPARTMENT OF HUMAN RESOURCES
# 375025          2018              1  DEPARTMENT OF HUMAN RESOURCES
# 375026          2018              1  DEPARTMENT OF HUMAN RESOURCES
# 375027          2018              1  DEPARTMENT OF HUMAN RESOURCES
# ...              ...            ...                            ...
# 1029041         2021              9  DEPARTMENT OF HUMAN RESOURCES
# 1029042         2021              9  DEPARTMENT OF HUMAN RESOURCES
# 1029043         2021              9  DEPARTMENT OF HUMAN RESOURCES
# 1029044         2021              9  DEPARTMENT OF HUMAN RESOURCES
# 1029045         2021              9  DEPARTMENT OF HUMAN RESOURCES
#
#                                DIV_NAME                MERCHANT  \
# 375023          Office of the Secretary             WW GRAINGER
# ...

# %%
div_count = df["DIV_NAME"].value_counts()
div_count.std()
# Out:
# 4650.1202896451

# %%
df["MERCHANDISE_AMT"].median()
# Out:
# 63.86

# %%
df["MERCHANDISE_AMT"].mean()
# Out:
# 398.5398188090282

# %%
df["MERCHANDISE_AMT"].plot(kind="hist")
plt.show()

# %%
df["MERCHANDISE_AMT"].std()
# Out:
# 2598.036128559533

# %%
plt.hist(df["MERCHANDISE_AMT"], range = [0,10000])
plt.show()

# %%
plt.hist(df["MERCHANDISE_AMT"], range = [0,1000])
plt.show()

# %%
df[df["MERCHANDISE_AMT"]<1000].count()
# Out:
# FISCAL_YEAR        969645
# FISCAL_PERIOD      969645
# DEPT_NAME          969645
# DIV_NAME           969645
# MERCHANT           969645
# CAT_DESCR          969645
# TRANS_DT           969645
# MERCHANDISE_AMT    969645
# dtype: int64

# %%
df["MERCHANDISE_AMT"].count()
# Out:
# 1040394

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040394 entries, 0 to 1040393
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   FISCAL_YEAR      1040394 non-null  int64
#  1   FISCAL_PERIOD    1040394 non-null  int64
#  2   DEPT_NAME        1040394 non-null  object
#  3   DIV_NAME         1040394 non-null  object
#  4   MERCHANT         1040394 non-null  object
#  5   CAT_DESCR        1040394 non-null  object
#  6   TRANS_DT         1040394 non-null  object
#  7   MERCHANDISE_AMT  1040394 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 63.5+ MB

# %%
df["TRANS_DT"] = df["TRANS_DT"].astype("datetime64")

# %% [markdown]
# # NUMBER TRANSACTIONS BY MONTH

# %%
df.groupby(df["TRANS_DT"].dt.month).count()
# Out:
#           FISCAL_YEAR  FISCAL_PERIOD  DEPT_NAME  DIV_NAME  MERCHANT  \
# TRANS_DT
# 1               87867          87867      87867     87867     87867
# 2               86798          86798      86798     86798     86798
# 3               95955          95955      95955     95955     95955
# 4               77412          77412      77412     77412     77412
# 5               82771          82771      82771     82771     82771
# 6               67371          67371      67371     67371     67371
# 7               83997          83997      83997     83997     83997
# 8              100748         100748     100748    100748    100748
# 9               98648          98648      98648     98648     98648
# 10             103950         103950     103950    103950    103950
# 11              79286          79286      79286     79286     79286
# 12              75591          75591      75591     75591     75591
#
#           CAT_DESCR  TRANS_DT  MERCHANDISE_AMT
# TRANS_DT
# ...

# %%
plt.bar(height = df.groupby(df["TRANS_DT"].dt.month).count()["TRANS_DT"],x = ["JAN", "FEB", "MAR", "APR","MAY","JUNE","JUL","AUG","SEP","OCT","NOV","DEC"])
plt.show()

# %%
df[(df['TRANS_DT'].dt.year != 2015)]
df[(df['TRANS_DT'].dt.year != 2021)]
# Out:
#          FISCAL_YEAR  FISCAL_PERIOD                     DEPT_NAME  \
# 0               2016              1                 DEPT OF STATE
# 1               2016              1     DEL TECH AND COMM COLLEGE
# 2               2016              1  DEPT OF HEALTH AND SOCIAL SV
# 3               2016              1                         LEGAL
# 4               2016              1                         LEGAL
# ...              ...            ...                           ...
# 1016155         2021              7   DEPT OF EDUCATION CONTINUED
# 1016184         2021              7     EARLY COLLEGE HIGH SCHOOL
# 1016187         2021              7     EARLY COLLEGE HIGH SCHOOL
# 1016189         2021              7     EARLY COLLEGE HIGH SCHOOL
# 1016190         2021              7     EARLY COLLEGE HIGH SCHOOL
#
#                                DIV_NAME                  MERCHANT  \
# 0         HUMAN RELATIONSCOMM FOR WOMEN        C/B GROUP REVERSAL
# ...

# %% [markdown]
# # NUMBER TRANSACTIONS BY MONTH/YEAR

# %%
df.groupby([df["TRANS_DT"].dt.year, df["TRANS_DT"].dt.month]).count().head()
# Out:
#                    FISCAL_YEAR  FISCAL_PERIOD  DEPT_NAME  DIV_NAME  MERCHANT  \
# TRANS_DT TRANS_DT
# 2015     4                   1              1          1         1         1
#          5                   2              2          2         2         2
#          6                1705           1705       1705      1705      1705
#          7               15067          15067      15067     15067     15067
#          8               15244          15244      15244     15244     15244
#
#                    CAT_DESCR  TRANS_DT  MERCHANDISE_AMT
# TRANS_DT TRANS_DT
# 2015     4                 1         1                1
#          5                 2         2                2
#          6              1705      1705             1705
#          7             15067     15067            15067
#          8             15244     15244            15244

# %%
byMonthYear = df[(df['TRANS_DT'].dt.year != 2015)]
byMonthYear = byMonthYear[(byMonthYear['TRANS_DT'].dt.year != 2016)]
byMonthYear = byMonthYear[(byMonthYear['TRANS_DT'].dt.year != 2017)]
byMonthYear = byMonthYear[(byMonthYear['TRANS_DT'].dt.year != 2018)]
byMonthYear = byMonthYear[(byMonthYear['TRANS_DT'].dt.year != 2021)]
byMonthYearGroup = byMonthYear.groupby([byMonthYear["TRANS_DT"].dt.year, df["TRANS_DT"].dt.month])
print( byMonthYearGroup.TRANS_DT.count())
# Out:
# TRANS_DT  TRANS_DT
# 2019      1           16009
#           2           15139
#           3           18158
#           4           17709
#           5           18911
#           6           13378
#           7           15802
#           8           18739
#           9           18143
#           10          20683
#           11          14467
#           12          13598
# 2020      1           16365
#           2           16899
#           3           14527
#           4            9604
#           5           10523
#           6            9332
#           7           10066
#           8           12128
#           9           13284
#           10          13585
#           11           9610
#           12          10557
# Name: TRANS_DT, dtype: int64

# %%
mask = (df["TRANS_DT"].dt.year >= 2019) & (df["TRANS_DT"].dt.year <= 2020)
cut19_20 = df.loc[mask]
cut19_20.head()
# Out:
#         FISCAL_YEAR  FISCAL_PERIOD           DEPT_NAME  \
# 658540         2019              7  LEGISLATIVE BRANCH
# 658541         2019              7  LEGISLATIVE BRANCH
# 658542         2019              7  LEGISLATIVE BRANCH
# 658543         2019              7  LEGISLATIVE BRANCH
# 658551         2019              7  LEGISLATIVE BRANCH
#
#                       DIV_NAME               MERCHANT  \
# 658540  General Assembly House      QUILL CORPORATION
# 658541  General Assembly House      QUILL CORPORATION
# 658542  General Assembly House      QUILL CORPORATION
# 658543  General Assembly House     VZWRLSS*MY VZ VB P
# 658551  General Assembly House  MR. NATURAL BOTTLED W
#
#                                               CAT_DESCR   TRANS_DT  \
# 658540  Stationery-Office Supplies-Printing Writing Pap 2019-01-15
# 658541  Stationery-Office Supplies-Printing Writing Pap 2019-01-23
# 658542  Stationery-Office Supplies-Printing Writing Pap 2019-01-17
# ...

# %%
byYearMonth.index.values
# Out:
# array([(2015, 4), (2015, 5), (2015, 6), (2015, 7), (2015, 8), (2015, 9),
#        (2015, 10), (2015, 11), (2015, 12), (2016, 1), (2016, 2),
#        (2016, 3), (2016, 4), (2016, 5), (2016, 6), (2016, 7), (2016, 8),
#        (2016, 9), (2016, 10), (2016, 11), (2016, 12), (2017, 1),
#        (2017, 2), (2017, 3), (2017, 4), (2017, 5), (2017, 6), (2017, 7),
#        (2017, 8), (2017, 9), (2017, 10), (2017, 11), (2017, 12),
#        (2018, 1), (2018, 2), (2018, 3), (2018, 4), (2018, 5), (2018, 6),
#        (2018, 7), (2018, 8), (2018, 9), (2018, 10), (2018, 11),
#        (2018, 12), (2019, 1), (2019, 2), (2019, 3), (2019, 4), (2019, 5),
#        (2019, 6), (2019, 7), (2019, 8), (2019, 9), (2019, 10), (2019, 11),
#        (2019, 12), (2020, 1), (2020, 2), (2020, 3), (2020, 4), (2020, 5),
#        (2020, 6), (2020, 7), (2020, 8), (2020, 9), (2020, 10), (2020, 11),
#        (2020, 12), (2021, 1), (2021, 2), (2021, 3)], dtype=object)

# %% [markdown]
# # NUMBER TRANSACTIONS BY YEAR

# %%
byYear = df.groupby(df["TRANS_DT"].dt.year).count()

# %%
byYear.head()
# Out:
#           FISCAL_YEAR  FISCAL_PERIOD  DEPT_NAME  DIV_NAME  MERCHANT  \
# TRANS_DT
# 2015            92161          92161      92161     92161     92161
# 2016           191160         191160     191160    191160    191160
# 2017           182497         182497     182497    182497    182497
# 2018           193710         193710     193710    193710    193710
# 2019           200736         200736     200736    200736    200736
#
#           CAT_DESCR  TRANS_DT  MERCHANDISE_AMT
# TRANS_DT
# 2015          92161     92161            92161
# 2016         191160    191160           191160
# 2017         182497    182497           182497
# 2018         193710    193710           193710
# 2019         200736    200736           200736

# %%
plt.bar(height = byYear["TRANS_DT"], x = byYear.index.values)
plt.show()

# %%
amountYear = df.groupby(df["TRANS_DT"].dt.year)["MERCHANDISE_AMT"].sum()

# %%
amountYear.head()
# Out:
# TRANS_DT
# 2015    3.741086e+07
# 2016    7.140070e+07
# 2017    7.273173e+07
# 2018    7.636380e+07
# 2019    7.338948e+07
# Name: MERCHANDISE_AMT, dtype: float64

# %%
plt.bar(height = amountYear, x = amountYear.index.values)
plt.show()

# %%
avgYear = df.groupby(df["TRANS_DT"].dt.year)["MERCHANDISE_AMT"].sum()/df.groupby(df["TRANS_DT"].dt.year)["MERCHANDISE_AMT"].count()

# %%
avgYear.head()
# Out:
# TRANS_DT
# 2015    405.929382
# 2016    373.512764
# 2017    398.536552
# 2018    394.217121
# 2019    365.601975
# Name: MERCHANDISE_AMT, dtype: float64

# %%
plt.plot(avgYear.index.values, avgYear )
plt.show()

# %%
medianYear = df.groupby(df["TRANS_DT"].dt.year)["MERCHANDISE_AMT"].median()
medianYear
# Out:
# TRANS_DT
# 2015    65.66
# 2016    60.67
# 2017    62.50
# 2018    59.88
# 2019    59.96
# 2020    74.92
# 2021    84.91
# Name: MERCHANDISE_AMT, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040394 entries, 0 to 1040393
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   FISCAL_YEAR      1040394 non-null  int64
#  1   FISCAL_PERIOD    1040394 non-null  int64
#  2   DEPT_NAME        1040394 non-null  object
#  3   DIV_NAME         1040394 non-null  object
#  4   MERCHANT         1040394 non-null  object
#  5   CAT_DESCR        1040394 non-null  object
#  6   TRANS_DT         1040394 non-null  datetime64[ns]
#  7   MERCHANDISE_AMT  1040394 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 63.5+ MB

# %%
df18 = df[df["FISCAL_YEAR"] == 2018]
df18.head()
# Out:
#         FISCAL_YEAR  FISCAL_PERIOD        DEPT_NAME      DIV_NAME  \
# 349727         2018              9  DEPT OF FINANCE    Accounting
# 370096         2018              1         JUDICIAL  Family Court
# 370182         2018              1         JUDICIAL  Family Court
# 371874         2018              1         JUDICIAL  Family Court
# 371917         2018              1         JUDICIAL  Family Court
#
#                       MERCHANT             CAT_DESCR   TRANS_DT  \
# 349727             APA HOUSING                Travel 2018-03-12
# 370096  DOVER POST ADVERTISING  Advertising Services 2017-06-30
# 370182  DOVER POST ADVERTISING  Advertising Services 2017-06-30
# 371874  DOVER POST ADVERTISING  Advertising Services 2017-06-30
# 371917  DOVER POST ADVERTISING  Advertising Services 2017-06-30
#
#         MERCHANDISE_AMT
# 349727           299.72
# 370096            30.00
# 370182           300.00
# 371874           120.00
# 371917            60.00

# %%
dep18 = df18.groupby(df18["DEPT_NAME"])

# %%
numTrans = dep18["MERCHANT"].count()

# %%
numTrans = numTrans.sort_values(ascending = False).head(5)

# %%
numTrans.head(5)
# Out:
# DEPT_NAME
# DEPT OF TRANSPORTATION            27356
# DEPT OF NATRL RES AND ENV CONT    22778
# DEPT OF CORRECTIONS               18877
# DEL TECH AND COMM COLLEGE         15956
# DEPT OF HEALTH AND SOCIAL SV      13604
# Name: MERCHANT, dtype: int64

# %%
top5 = pd.DataFrame(dep18.get_group("DEPT OF TRANSPORTATION"))
top5.append(dep18.get_group("DEPT OF NATRL RES AND ENV CONT"))
top5.append(dep18.get_group("DEPT OF CORRECTIONS"))
top5.append(dep18.get_group("DEL TECH AND COMM COLLEGE"))
top5.append(dep18.get_group("DEPT OF HEALTH AND SOCIAL SV"))
# Out:
#         FISCAL_YEAR  FISCAL_PERIOD                     DEPT_NAME  \
# 377257         2018              1        DEPT OF TRANSPORTATION
# 377678         2018              1        DEPT OF TRANSPORTATION
# 381030         2018              1        DEPT OF TRANSPORTATION
# 381031         2018              1        DEPT OF TRANSPORTATION
# 381032         2018              1        DEPT OF TRANSPORTATION
# ...             ...            ...                           ...
# 549981         2018             12  DEPT OF HEALTH AND SOCIAL SV
# 549982         2018             12  DEPT OF HEALTH AND SOCIAL SV
# 549983         2018             12  DEPT OF HEALTH AND SOCIAL SV
# 549984         2018             12  DEPT OF HEALTH AND SOCIAL SV
# 549985         2018             12  DEPT OF HEALTH AND SOCIAL SV
#
#                        DIV_NAME              MERCHANT  \
# 377257    Maintenance Districts        TOOLS And MORE
# 377678           Administration    SEARS ROEBUCK 7019
# ...

# %%
top5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27356 entries, 377257 to 556338
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FISCAL_YEAR      27356 non-null  int64
#  1   FISCAL_PERIOD    27356 non-null  int64
#  2   DEPT_NAME        27356 non-null  object
#  3   DIV_NAME         27356 non-null  object
#  4   MERCHANT         27356 non-null  object
#  5   CAT_DESCR        27356 non-null  object
#  6   TRANS_DT         27356 non-null  datetime64[ns]
#  7   MERCHANDISE_AMT  27356 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 1.9+ MB

# %%
import scipy
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.cluster import KMeans

# %%
top5.head(10)
# Out:
#         FISCAL_YEAR  FISCAL_PERIOD               DEPT_NAME  \
# 377257         2018              1  DEPT OF TRANSPORTATION
# 377678         2018              1  DEPT OF TRANSPORTATION
# 381030         2018              1  DEPT OF TRANSPORTATION
# 381031         2018              1  DEPT OF TRANSPORTATION
# 381032         2018              1  DEPT OF TRANSPORTATION
# 381033         2018              1  DEPT OF TRANSPORTATION
# 381034         2018              1  DEPT OF TRANSPORTATION
# 381035         2018              1  DEPT OF TRANSPORTATION
# 381036         2018              1  DEPT OF TRANSPORTATION
# 381037         2018              1  DEPT OF TRANSPORTATION
#
#                        DIV_NAME                MERCHANT  \
# 377257    Maintenance Districts          TOOLS And MORE
# 377678           Administration      SEARS ROEBUCK 7019
# 381030  Office Of The Secretary         HILTON AT PENNS
# 381031  Office Of The Secretary      VZWRLSS*MY VZ VB P
# ...

# %% [markdown]
# # Categorical Spending

# %%
df.head()
# Out:
#    FISCAL_YEAR  FISCAL_PERIOD                     DEPT_NAME  \
# 0         2016              1                 DEPT OF STATE
# 1         2016              1     DEL TECH AND COMM COLLEGE
# 2         2016              1  DEPT OF HEALTH AND SOCIAL SV
# 3         2016              1                         LEGAL
# 4         2016              1                         LEGAL
#
#                          DIV_NAME                  MERCHANT  \
# 0   HUMAN RELATIONSCOMM FOR WOMEN        C/B GROUP REVERSAL
# 1  DTCC - OFFICE OF THE PRESIDENT                CA PUCCINO
# 2         GOVERNOR BACON HOSPITAL         CHARGEBACK CREDIT
# 3      OFFICE OF ATTORNEY GENERAL  DOJ INTERNAL TRANSACTION
# 4      OFFICE OF ATTORNEY GENERAL  DOJ INTERNAL TRANSACTION
#
#                    CAT_DESCR    TRANS_DT  MERCHANDISE_AMT
# 0       INTERNAL TRANSACTION  04/02/2015           105.73
# 1  EATING PLACES RESTAURANTS  05/27/2015             3.79
# 2       INTERNAL TRANSACTION  05/29/2015         -1678.57
# ...

# %%
len(df["CAT_DESCR"].unique())
# Out:
# 497

# %% [markdown]
# # Department Analysis

# %%
tech_purchases = df[df.DEPT_NAME == "DEPT OF TECHNOLOGY AND INFOR"]["MERCHANDISE_AMT"]

tech_range = list(range(1,len(tech_purchases)+1))
plt.scatter(y = tech_purchases, x = list(range(1,len(tech_purchases)+1)))
plt.show()
plt.hist(tech_purchases)
plt.show()
